# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Load job market
dfmain = pd.read_csv("C:/Users/mkuod/OneDrive/Documents/Griffith University/Second year/First semster/Data Analytics/Lab 2/job-market(3).csv")
dfmain.head()
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 2                             LB Creative Pty Ltd  2018-10-07T00:00:00.000Z
# 3                          Anaconda Group Pty Ltd  2018-10-07T00:00:00.000Z
# 4  Commonwealth Bank - Business & Private Banking  2018-10-07T00:00:00.000Z
#
#                   Location                         Area  \
# 0                   Sydney  North West & Hills District
# ...

# %%
# %matplotlib inline

# %%
df = dfmain[['Title', 'Location']]

# %%
df
# Out:
#                                                    Title  \
# 0                               Casual Stock Replenisher
# 1                               Casual Stock Replenisher
# 2      RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3                                  Team member - Belrose
# 4      Business Banking Contact Centre Specialist, Ni...
# ...                                                  ...
# 40784                                                NaN
# 40785                                                NaN
# 40786                                                NaN
# 40787                                                NaN
# 40788                                                NaN
#
#                       Location
# 0                       Sydney
# 1        Richmond & Hawkesbury
# 2                     Brisbane
# 3      Gosford & Central Coast
# 4                       Sydney
# ...                        ...
# 40784                      NaN
# ...

# %%
#OPTIONAL
locationDf = df[df['Location'].isna()==False]
locationDf = locationDf.groupby('Location').count()
locationDf.head()
# Out:
#                           Title
# Location
# ACT                         238
# Adelaide                    390
# Adelaide Hills & Barossa     19
# Albany & Great Southern      10
# Albury Area                  19

# %%
# Job by Location 
locationDf.plot(kind='bar', figsize=(10,6), ylabel='Title')
# Out:
# <AxesSubplot:xlabel='Location', ylabel='Title'>

# %%
locationDf.plot(kind='barh', figsize=(40,20))
# Out:
# <AxesSubplot:ylabel='Location'>

# %%
#salary ranges plot
dfsalary = dfmain[['LowestSalary', 'HighestSalary']]
dfsalary
# Out:
#        LowestSalary  HighestSalary
# 0               0.0           30.0
# 1               0.0           30.0
# 2               0.0           30.0
# 3               0.0           30.0
# 4               0.0           30.0
# ...             ...            ...
# 40784           NaN            NaN
# 40785           NaN            NaN
# 40786           NaN            NaN
# 40787           NaN            NaN
# 40788           NaN            NaN
#
# [40789 rows x 2 columns]

# %%
dfsalary = dfsalary[dfsalary['LowestSalary'].isna()==False]
dfsalary = locationDf.groupby('Location').count()
dfsalary.head()

# %%
#OPTIONAL

locationDf = df[df['Location'].isna()==False]
locationDf = locationDf.groupby('Location').count()
locationDf['Location'] = locationDf.index
locationDf['Count'] = locationDf["Id"]
locationDf.head()
# Out:
#                            Id  Title  Company  Date  Area  Classification  \
# Location
# ACT                       238    238      235   238     0             238
# Adelaide                  390    390      356   390     0             390
# Adelaide Hills & Barossa   19     19       18    19     0              19
# Albany & Great Southern    10     10       10    10     0              10
# Albury Area                19     19       18    19     0              19
#
#                           SubClassification  Requirement  FullDescription  \
# Location
# ACT                                     238          238              235
# Adelaide                                390          390              374
# Adelaide Hills & Barossa                 19           19               19
# Albany & Great Southern                  10           10               10
# Albury Area                              19           19               19
#
# ...

# %%
#OPTIONAL

# %matplotlib inline
# Pie char for job market share of cities
from matplotlib import cm
# Out:
# Text(50.0, 0.5, '')
